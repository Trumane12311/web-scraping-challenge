# %%
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pymongo

# %%
#Setup Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Get LATEST driver version for 90.0.4430
# Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/bt4ever/.wdm/drivers/chromedriver/mac64/90.0.4430.24]

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)

# %%
for x in range(1, 6):

    html = browser.html
    soup = bs(html, 'html.parser')

    news_titles = soup.find_all('div', class_='content_title')
    news_paragraphs = soup.find_all('div', class_='article_teaser_body')

    for news_title in news_titles:
        print(f'News Article: {news_title.text}')
    for news_paragraph in news_paragraphs:
        print(f'Teaser: {news_paragraph.text}')

    browser.links.find_by_partial_text('More').click()
# Out:
# News Article: NASA's Perseverance Rover Is Midway to Mars
# News Article: NASA's Mars 2020 Rover Closer to Getting Its Name
# News Article: NASA-JPL Names 'Rolling Stones Rock' on Mars
# News Article: NASA's Mars 2020 Heads Into the Test Chamber
# News Article: NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb
# News Article: NASA's Perseverance Rover Attached to Atlas V Rocket
# News Article: Robotic Toolkit Added to NASA's Mars 2020 Rover
# News Article: Screening Soon: 'The Pathfinders' Trains Lens on Mars
# News Article: My Culture, My Voice
# News Article: NASA Updates Mars 2020 Mission Environmental Review
# News Article: NASA's Curiosity Rover Finds an Ancient Oasis on Mars
# News Article: Naming a NASA Mars Rover Can Change Your Life
# News Article: Mars Is Getting a New Robotic Meteorologist
# News Article: Alabama High School Student Names NASA's Mars Helicopter
# News Article: A Year of Surprising Science From NASA's InSight Mars Mission
# ...

# %%
articles = soup.find_all('div', class_="container")
articles
# Out:
# [<div class="container">
#              <h1>News</h1>
#              <div class="col-md-12 filter">
#                 <div class="row">
#                    <div class="col-md-3 search_binder">
#                       <input class="search_field" name="search" type="text"/>
#                       <input class="search_submit" name="search" type="text"/>
#                    </div>
#                    <div class="col-md-3">
#                       <select aria-label="Default select example" class="form-select" id="year">
#                          <option selected="">Latest</option>
#
#                       </select>
#                    </div>
#                    <div class="col-md-3">
#                       <select aria-label="Default select example" class="form-select" id="cat">
#                          <option selected="">All Categories</option>
#
#                       </select>
#                    </div>
#                    <div class="col-md-3">
# ...

# %%
browser.quit()
